# %%
import pandas as pd
print(pd)
# Out:
# Running cells with '.venv (Python 3.11.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/DeepX/DeepX-Hackathon-2026/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
